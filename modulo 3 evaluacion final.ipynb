# %% [markdown]
# Ejercicio final de evaluacion - Módulo 3

# %%
# Importamos librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Para poder visualizar todas las columnas de los DataFrames

pd.set_option('display.max_columns', None)

# %%
# Cargamos los DataFrames

df_flight = pd.read_csv('Customer Flight Activity.csv')
df_loyalty = pd.read_csv('Customer Loyalty History.csv')

# %% [markdown]
# Fase 1: Exploración y Limpieza

# %% [markdown]
# 1. Exploración Inicial:

# %%
# Visualizamos los DataFrame para ver algunas de sus caracterísicas

df_flight.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
df_flight.shape
# Out:
# (405624, 10)

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
df_loyalty.head()
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
# ...

# %%
df_loyalty.shape
# Out:
# (16737, 16)

# %%
df_loyalty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
# ...

# %%
# Visualizamos estadísiticas básicas

df_flight.describe()
# Out:
#        Loyalty Number           Year          Month  Flights Booked  \
# count   405624.000000  405624.000000  405624.000000   405624.000000
# mean    550037.873084    2017.500000       6.500000        4.115052
# std     258935.286969       0.500001       3.452057        5.225518
# min     100018.000000    2017.000000       1.000000        0.000000
# 25%     326961.000000    2017.000000       3.750000        0.000000
# 50%     550834.000000    2017.500000       6.500000        1.000000
# 75%     772194.000000    2018.000000       9.250000        8.000000
# max     999986.000000    2018.000000      12.000000       21.000000
#
#        Flights with Companions  Total Flights       Distance  \
# count            405624.000000  405624.000000  405624.000000
# mean                  1.031805       5.146858    1208.880059
# std                   2.076869       6.521227    1433.155320
# min                   0.000000       0.000000       0.000000
# ...

# %%
df_loyalty.describe()
# Out:
#        Loyalty Number         Salary           CLV  Enrollment Year  \
# count    16737.000000   12499.000000  16737.000000     16737.000000
# mean    549735.880445   79245.609409   7988.896536      2015.253211
# std     258912.132453   35008.297285   6860.982280         1.979111
# min     100018.000000  -58486.000000   1898.010000      2012.000000
# 25%     326603.000000   59246.500000   3980.840000      2014.000000
# 50%     550434.000000   73455.000000   5780.180000      2015.000000
# 75%     772019.000000   88517.500000   8940.580000      2017.000000
# max     999986.000000  407228.000000  83325.380000      2018.000000
#
#        Enrollment Month  Cancellation Year  Cancellation Month
# count      16737.000000        2067.000000         2067.000000
# mean           6.669116        2016.503145            6.962748
# std            3.398958           1.380743            3.455297
# min            1.000000        2013.000000            1.000000
# ...

# %%
# Comprobamos valores nulos

df_flight.isnull().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %%
df_loyalty.isnull().sum()
# Out:
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64

# %%
# Comprobamos si hay registros duplicados

duplicados_flight = df_flight.duplicated().sum()
duplicados_loyalty = df_loyalty.duplicated().sum()

print(f'Duplicados en Customer Flight Analysis: {duplicados_flight}')
print(f'Duplicados en Customer Loyalty History: {duplicados_loyalty}')
# Out:
# Duplicados en Customer Flight Analysis: 1864
# Duplicados en Customer Loyalty History: 0

# %%
# Unimos los 2 DataFrames por la columna en común 'Loyalty Number'

df_unido = df_flight.merge(df_loyalty, left_on = 'Loyalty Number', right_on = 'Loyalty Number') # OTRA FORMA: df_combinado = pd.merge(df_flight, df_loyalty, on='Loyalty Number')
df_unido
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 1               100102  2017      1              10                        4
# 2               100140  2017      1               6                        0
# 3               100214  2017      1               0                        0
# 4               100272  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
# ...

# %%
# Revisamos el numero de registros después de la unión

df_unido.shape
# Out:
# (405624, 25)

# %% [markdown]
# 2. Limpieza de Datos:

# %%
# 2.1 Elimina o trata los valores nulos, si los hay, en las columnas clave para asegurar que los datos estén completos

# # Comprobamos valores nulos en el DataFrame combinado

nulos = df_unido.isnull().sum()
nulos
# Out:
# Loyalty Number                      0
# Year                                0
# Month                               0
# Flights Booked                      0
# Flights with Companions             0
# Total Flights                       0
# Distance                            0
# Points Accumulated                  0
# Points Redeemed                     0
# Dollar Cost Points Redeemed         0
# Country                             0
# Province                            0
# City                                0
# Postal Code                         0
# Gender                              0
# Education                           0
# Salary                         102672
# Marital Status                      0
# Loyalty Card                        0
# CLV                                 0
# Enrollment Type                     0
# Enrollment Year                     0
# Enrollment Month                    0
# Cancellation Year              355560
# Cancellation Month             355560
# ...

# %%
# Analizamos el porcentaje de nulos

nulos2 = df_unido.isnull().sum()/df_unido.shape[0]*100
# % nulos ordenados de mayor a menor
print("\nPORCENTAJE DE NULOS POR COLUMNAS:")
print(nulos2.sort_values(ascending=False))
#nulos.sort_values(ascending=False)
# Out:
# PORCENTAJE DE NULOS POR COLUMNAS:
# Cancellation Month             87.657535
# Cancellation Year              87.657535
# Salary                         25.312112
# Year                            0.000000
# Flights with Companions         0.000000
# Total Flights                   0.000000
# Month                           0.000000
# Flights Booked                  0.000000
# Loyalty Number                  0.000000
# Points Redeemed                 0.000000
# Points Accumulated              0.000000
# Distance                        0.000000
# Dollar Cost Points Redeemed     0.000000
# City                            0.000000
# Postal Code                     0.000000
# Province                        0.000000
# Country                         0.000000
# Education                       0.000000
# Gender                          0.000000
# Marital Status                  0.000000
# Loyalty Card                    0.000000
# Enrollment Type                 0.000000
# ...

# %%
# Definimos columnas clave a verificar

columnas_clave = ['Loyalty Number', 'Flights Booked', 'Total Flights', 'Salary' ,'Gender', 'Education', 'Province', 'Marital Status', 'Loyalty Card', 'Distance', 'Points Accumulated']

# %%
# Analizamos graficamente valores de columna 'Salary' y vemos no es simética

plt.figure(figsize=(8, 6))
plt.hist(df_unido['Salary'], bins=30, color='blue', edgecolor= 'black')
plt.title('Histograma de Salarios')
plt.xlabel('Salario')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Sacamos la mediana para la columna Salary

float(df_unido['Salary'].median())
# Out:
# 73479.0

# %%
# Imputamos los valores nulos en columna 'Salary'con la media

mediana_salary = float(df_unido['Salary'].median())
df_unido['Salary'] = df_unido['Salary'].fillna(mediana_salary)
df_unido.isnull().sum()
# Out:
# Loyalty Number                      0
# Year                                0
# Month                               0
# Flights Booked                      0
# Flights with Companions             0
# Total Flights                       0
# Distance                            0
# Points Accumulated                  0
# Points Redeemed                     0
# Dollar Cost Points Redeemed         0
# Country                             0
# Province                            0
# City                                0
# Postal Code                         0
# Gender                              0
# Education                           0
# Salary                              0
# Marital Status                      0
# Loyalty Card                        0
# CLV                                 0
# Enrollment Type                     0
# Enrollment Year                     0
# Enrollment Month                    0
# Cancellation Year              355560
# Cancellation Month             355560
# ...

# %%
df_unido.isnull().sum()
# Out:
# Loyalty Number                      0
# Year                                0
# Month                               0
# Flights Booked                      0
# Flights with Companions             0
# Total Flights                       0
# Distance                            0
# Points Accumulated                  0
# Points Redeemed                     0
# Dollar Cost Points Redeemed         0
# Country                             0
# Province                            0
# City                                0
# Postal Code                         0
# Gender                              0
# Education                           0
# Salary                              0
# Marital Status                      0
# Loyalty Card                        0
# CLV                                 0
# Enrollment Type                     0
# Enrollment Year                     0
# Enrollment Month                    0
# Cancellation Year              355560
# Cancellation Month             355560
# ...

# %%
df_unido.dtypes
# Out:
# Loyalty Number                   int64
# Year                             int64
# Month                            int64
# Flights Booked                   int64
# Flights with Companions          int64
# Total Flights                    int64
# Distance                         int64
# Points Accumulated             float64
# Points Redeemed                  int64
# Dollar Cost Points Redeemed      int64
# Country                         object
# Province                        object
# City                            object
# Postal Code                     object
# Gender                          object
# Education                       object
# Salary                         float64
# Marital Status                  object
# Loyalty Card                    object
# CLV                            float64
# Enrollment Type                 object
# Enrollment Year                  int64
# Enrollment Month                 int64
# Cancellation Year              float64
# ...

# %%
df_unido.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed',
#        'Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education',
#        'Salary', 'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type',
#        'Enrollment Year', 'Enrollment Month', 'Cancellation Year',
#        'Cancellation Month'],
#       dtype='object')

# %%
df_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
#  10  Country                      405624 non-null  object
#  11  Province                     405624 non-null  object
# ...

# %%
# Revisamos los valores unicos que son texto

for col in df_unido.select_dtypes(include='object'):
    print(col)
    print('-----------------------------')
    print(df_unido[col].unique())
# Out:
# Country
# -----------------------------
# ['Canada']
# Province
# -----------------------------
# ['Alberta' 'Ontario' 'British Columbia' 'Saskatchewan' 'Quebec'
#  'Newfoundland' 'Manitoba' 'New Brunswick' 'Nova Scotia'
#  'Prince Edward Island' 'Yukon']
# City
# -----------------------------
# ['Edmonton' 'Toronto' 'Dawson Creek' 'Vancouver' 'Regina' 'Montreal'
#  'Sudbury' 'Quebec City' 'Peace River' "St. John's" 'Tremblant' 'Ottawa'
#  'Trenton' 'Winnipeg' 'Thunder Bay' 'West Vancouver' 'Fredericton'
#  'London' 'Halifax' 'Moncton' 'Banff' 'Kingston' 'Whistler'
#  'Charlottetown' 'Hull' 'Victoria' 'Calgary' 'Kelowna' 'Whitehorse']
# Postal Code
# -----------------------------
# ['T9G 1W3' 'M1R 4K3' 'U5I 4F1' 'V5R 1W3' 'P1L 8X8' 'P1J 8T7' 'S6J 3G0'
#  'H2T 9K8' 'V6E 3D9' 'M5V 1G5' 'H2Y 4R4' 'M8Y 4K8' 'V6E 3Z3' 'G1B 3L5'
#  'T9O 2W2' 'A1C 6H9' 'H5Y 2S9' 'K1F 2R2' 'K8V 4B2' 'R3R 3T4' 'P1W 1K4'
#  'K8T 5M5' 'V6V 8Z3' 'M2M 7K8' 'E3B 2H2' 'M5B 3E4' 'H2Y 2W2' 'P5S 6R4'
# ...

# %%
df_unido_copy = df_unido

# %%
df_unido_copy.dtypes
# Out:
# Loyalty Number                   int64
# Year                             int64
# Month                            int64
# Flights Booked                   int64
# Flights with Companions          int64
# Total Flights                    int64
# Distance                         int64
# Points Accumulated               int64
# Points Redeemed                  int64
# Dollar Cost Points Redeemed      int64
# Country                         object
# Province                        object
# City                            object
# Postal Code                     object
# Gender                          object
# Education                       object
# Salary                         float64
# Marital Status                  object
# Loyalty Card                    object
# CLV                            float64
# Enrollment Type                 object
# Enrollment Year                  int64
# Enrollment Month                 int64
# Cancellation Year              float64
# ...

# %%
# Cambiamos el tipo de valor de la columna Points Accumulated, resto no trabajamos porque no las vamos a analizar

df_unido_copy['Points Accumulated'] = df_unido_copy['Points Accumulated'].astype(int)

# %%
# Revisamos columnas Enrollment Year y Enrollment Month para ver las variables unicas que contienen, no importortantes para el análisis, no trabajamos sobre ellas

Cancellation_Year = df_loyalty['Cancellation Year'].unique()
Cancellation_Month = df_loyalty['Cancellation Month'].unique()
print(Cancellation_Year)
print('-------')
print(Cancellation_Month)
# Out:
# [  nan 2018. 2015. 2017. 2014. 2016. 2013.]
# -------
# [nan  1. 12.  4.  2.  7. 11.  5.  6. 10.  8.  9.  3.]

# %%
df_unido_copy.dtypes
# Out:
# Loyalty Number                   int64
# Year                             int64
# Month                            int64
# Flights Booked                   int64
# Flights with Companions          int64
# Total Flights                    int64
# Distance                         int64
# Points Accumulated               int64
# Points Redeemed                  int64
# Dollar Cost Points Redeemed      int64
# Country                         object
# Province                        object
# City                            object
# Postal Code                     object
# Gender                          object
# Education                       object
# Salary                         float64
# Marital Status                  object
# Loyalty Card                    object
# CLV                            float64
# Enrollment Type                 object
# Enrollment Year                  int64
# Enrollment Month                 int64
# Cancellation Year              float64
# ...

# %% [markdown]
# Fase 2: Visualización

# %% [markdown]
# Usando las herramientas de visualización contesta a las siguientes gráficas

# %%
# 1. ¿Cómo se distribuye la cantidad de vuelos reservados por mes durante el año?

vuelos_por_mes = df_unido_copy.groupby(['Year', 'Month']).size().reset_index(name='Cantidad_vuelos')
vuelos_por_mes
# Out:
#     Year  Month  Cantidad_vuelos
# 0   2017      1            16901
# 1   2017      2            16901
# 2   2017      3            16901
# 3   2017      4            16901
# 4   2017      5            16901
# 5   2017      6            16901
# 6   2017      7            16901
# 7   2017      8            16901
# 8   2017      9            16901
# 9   2017     10            16901
# 10  2017     11            16901
# 11  2017     12            16901
# 12  2018      1            16901
# 13  2018      2            16901
# 14  2018      3            16901
# 15  2018      4            16901
# 16  2018      5            16901
# 17  2018      6            16901
# 18  2018      7            16901
# 19  2018      8            16901
# 20  2018      9            16901
# 21  2018     10            16901
# 22  2018     11            16901
# 23  2018     12            16901

# %%
df_unido_copy['Year'].unique()
# Out:
# array([2017, 2018])

# %%
# 2. ¿Existe una relación entre la distancia de los vuelos y los puntos acumulados por los cliente? Del resultado de la gráfica se pude conluir que la distancia de los vuelos no incide principalmente en los puntos acumulados

plt.figure(figsize=(8,6))
plt.scatter(df_unido_copy['Distance'], df_unido_copy['Points Accumulated'], color='blue')


plt.title('Relación entre distancia de vuelos y puntos acumulados')
plt.xlabel('Distancia del Vuelo')
plt.ylabel('Puntos Acumulados')
plt.grid()


plt.show()

# %%
# 3. ¿Cuál es la distribución de los clientes por provincia o estado?

distribucion_por_provincia = df_unido_copy['Province'].value_counts().reset_index()

distribucion_por_provincia
# Out:
#                 Province   count
# 0                Ontario  130896
# 1       British Columbia  106848
# 2                 Quebec   79968
# 3                Alberta   23400
# 4               Manitoba   15984
# 5          New Brunswick   15432
# 6            Nova Scotia   12576
# 7           Saskatchewan    9936
# 8           Newfoundland    6312
# 9                  Yukon    2688
# 10  Prince Edward Island    1584

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Province', data=df_unido_copy, color = 'c', order=distribucion_por_provincia)


plt.title('Distribución de clientes por provincia')
plt.xlabel('Provincia')
plt.ylabel('Cantidad de clientes')
plt.xticks(rotation=45) 
plt.grid(axis='y')

plt.show()

# %%
# 4. ¿Cómo se compara el salario promedio entre los diferentes niveles educativos de los clientes?

resultado_salario_promedio = df_unido_copy.groupby('Education')['Salary'].mean()
resultado_salario_promedio
# Out:
# Education
# Bachelor                 72476.211860
# College                  79268.825953
# Doctor                  178335.439516
# High School or Below     60986.544192
# Master                  103767.494163
# Name: Salary, dtype: float64

# %%
# 5. ¿Cuál es la proporción de clientes con diferentes tipos de tarjetas de fidelidad?

clientes_por_tipo_tarjeta = df_unido_copy['Loyalty Card'].value_counts()
clientes_por_tipo_tarjeta

proporcion_clientes = clientes_por_tipo_tarjeta / len(df_unido_copy)
proporcion_clientes
# Out:
# Loyalty Card
# Star      0.454174
# Nova      0.339152
# Aurora    0.206674
# Name: count, dtype: float64

# %%
# 6. ¿Cómo se distribuyen los clientes según su estado civil y género?

# %%
# Contar el número de clientes por género y estado civil

total_clientes = df_unido_copy.groupby(['Gender', 'Marital Status']).size().reset_index(name='counts')
total_clientes
# Out:
#    Gender Marital Status  counts
# 0  Female       Divorced   30888
# 1  Female        Married  117816
# 2  Female         Single   54936
# 3    Male       Divorced   30288
# 4    Male        Married  117984
# 5    Male         Single   53712

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Marital Status', y='counts', hue='Gender', data=total_clientes)
plt.title('Distribución de Clientes por Estado Civil y Género')
plt.xlabel('Estado Civil')
plt.ylabel('Cantidad de Clientes')
plt.legend(title='Género')
plt.show()
